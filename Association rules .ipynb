# %% [markdown]
# Association Rules
# Let's say you are a machine learning engineer working for a clothing company and you want to adopt new strategies to improve the company's profit.
#
# Use this dataset and the association rules mining to find new marketing plans.
#
# Note that one of the strategies can be based on which items should be put together
#
# dataset = [['Skirt', 'Sneakers', 'Scarf', 'Pants', 'Hat'],
#
#     ['Sunglasses', 'Skirt', 'Sneakers', 'Pants', 'Hat'],
#
#     ['Dress', 'Sandals', 'Scarf', 'Pants', 'Heels'],
#
#     ['Dress', 'Necklace', 'Earrings', 'Scarf', 'Hat', 'Heels', 'Hat'],
#
#    ['Earrings', 'Skirt', 'Skirt', 'Scarf', 'Shirt', 'Pants']]
#
# Bonus: Try to do some visualization before applying the Apriori algorithm.
#
# Let's do the same checkpoint but with a bigger dataset!

# %%
dataset = [['Skirt', 'Sneakers', 'Scarf', 'Pants', 'Hat'],

    ['Sunglasses', 'Skirt', 'Sneakers', 'Pants', 'Hat'],

    ['Dress', 'Sandals', 'Scarf', 'Pants', 'Heels'],

    ['Dress', 'Necklace', 'Earrings', 'Scarf', 'Hat', 'Heels', 'Hat'],

   ['Earrings', 'Skirt', 'Skirt', 'Scarf', 'Shirt', 'Pants']]

# %%
import mlxtend
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
te=TransactionEncoder()
te_ary=te.fit(dataset).transform(dataset)    #Apply one-hot-encoding on our dataset
df=pd.DataFrame(te_ary, columns=te.columns_)  #Creating a new DataFrame from our Numpy array
df
# Out:
#    Dress  Earrings    Hat  Heels  Necklace  Pants  Sandals  Scarf  Shirt  \
# 0  False     False   True  False     False   True    False   True  False
# 1  False     False   True  False     False   True    False  False  False
# 2   True     False  False   True     False   True     True   True  False
# 3   True      True   True   True      True  False    False   True  False
# 4  False      True  False  False     False   True    False   True   True
#
#    Skirt  Sneakers  Sunglasses
# 0   True      True       False
# 1   True      True        True
# 2  False     False       False
# 3  False     False       False
# 4   True     False       False

# %%
#DataViz
import matplotlib.pyplot as plt
for col in df.columns: 
    df[col].value_counts().plot.bar(rot=0)
    plt.title(col)
    plt.show()

# %%
from mlxtend.frequent_patterns import apriori
apriori(df, min_support=0.6) #Let’s select itemsets with a minimum of 60% support
#Apriori returns by default the column index of the item
# Out:
#    support itemsets
# 0      0.6      (2)
# 1      0.8      (5)
# 2      0.8      (7)
# 3      0.6      (9)
# 4      0.6   (5, 7)
# 5      0.6   (9, 5)

# %%
frequent_itemsets=apriori(df, min_support=0.6, use_colnames=True) #Instead of column indices we can use column names.
frequent_itemsets #Support with Column Names
# Out:
#    support        itemsets
# 0      0.6           (Hat)
# 1      0.8         (Pants)
# 2      0.8         (Scarf)
# 3      0.6         (Skirt)
# 4      0.6  (Scarf, Pants)
# 5      0.6  (Skirt, Pants)

# %% [markdown]
# The best sellers are Pants and Scarf 80%. (Scarf, pants) and (skirt, pants) are always bought together.

# %%
from mlxtend.frequent_patterns import association_rules 
association_rules(frequent_itemsets,metric="confidence",min_threshold=0.7) # associate itemsets with confidence over 70%.
# Out:
#   antecedents consequents  antecedent support  consequent support  support  \
# 0     (Scarf)     (Pants)                 0.8                 0.8      0.6
# 1     (Pants)     (Scarf)                 0.8                 0.8      0.6
# 2     (Skirt)     (Pants)                 0.6                 0.8      0.6
# 3     (Pants)     (Skirt)                 0.8                 0.6      0.6
#
#    confidence    lift  leverage  conviction
# 0        0.75  0.9375     -0.04         0.8
# 1        0.75  0.9375     -0.04         0.8
# 2        1.00  1.2500      0.12         inf
# 3        0.75  1.2500      0.12         1.6

# %% [markdown]
# Skirt and Pants have a confidence of 100% thus they are always bought together.

# %%
from mlxtend.frequent_patterns import association_rules 
association_rules(frequent_itemsets,metric="lift",min_threshold=1.25)
# Out:
#   antecedents consequents  antecedent support  consequent support  support  \
# 0     (Skirt)     (Pants)                 0.6                 0.8      0.6
#
#    confidence  lift  leverage  conviction
# 0         1.0  1.25      0.12         inf

# %% [markdown]
# If a customer buys a skirt, she will eventually buy pants. Overall, it's rather to buy skirts and pants together rather to buy skirts alone.

# %% [markdown]
# SECOND DATASET

# %%
import csv 
with open('C:/Users/rania/Downloads/Market_Basket_Optimisation.csv', 'r') as csvfile: 
    lines=csv.reader(csvfile)
    Data=list(lines)
Data
# Out:
# [['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice',
#   'low fat yogurt',
#   'green tea',
#   'honey',
#   'salad',
#   'mineral water',
#   'salmon',
#   'antioxydant juice',
#   'frozen smoothie',
#   'spinach',
#   'olive oil'],
#  ['burgers', 'meatballs', 'eggs'],
#  ['chutney'],
#  ['turkey', 'avocado'],
#  ['mineral water', 'milk', 'energy bar', 'whole wheat rice', 'green tea'],
#  ['low fat yogurt'],
#  ['whole wheat pasta', 'french fries'],
#  ['soup', 'light cream', 'shallot'],
#  ['frozen vegetables', 'spaghetti', 'green tea'],
#  ['french fries'],
#  ['eggs', 'pet food'],
#  ['cookies'],
#  ['turkey', 'burgers', 'mineral water', 'eggs', 'cooking oil'],
#  ['spaghetti', 'champagne', 'cookies'],
#  ['mineral water', 'salmon'],
#  ['mineral water'],
#  ['shrimp',
#   'chocolate',
#   'chicken',
#   'honey',
#   'oil',
#   'cooking oil',
# ...

# %%
te=TransactionEncoder()
te_ary=te.fit(Data).transform(Data)    #Apply one-hot-encoding on our dataset
df1=pd.DataFrame(te_ary, columns=te.columns_)  #Creating a new DataFrame from our Numpy array
df1
# Out:
#        asparagus  almonds  antioxydant juice  asparagus  avocado  babies food  \
# 0          False     True               True      False     True        False
# 1          False    False              False      False    False        False
# 2          False    False              False      False    False        False
# 3          False    False              False      False     True        False
# 4          False    False              False      False    False        False
# ...          ...      ...                ...        ...      ...          ...
# 7496       False    False              False      False    False        False
# 7497       False    False              False      False    False        False
# 7498       False    False              False      False    False        False
# 7499       False    False              False      False    False        False
# 7500       False    False              False      False    False        False
#
# ...

# %%
frequent_itemsets=apriori(df1, min_support=0.2, use_colnames=True)
frequent_itemsets
# Out:
#     support         itemsets
# 0  0.238368  (mineral water)

# %% [markdown]
# Mineral water is the most frequent item with a percentage of 23%.

# %%
frequent_itemsets=apriori(df1, min_support=0.1, use_colnames=True)
frequent_itemsets
# Out:
#     support         itemsets
# 0  0.163845      (chocolate)
# 1  0.179709           (eggs)
# 2  0.170911   (french fries)
# 3  0.132116      (green tea)
# 4  0.129583           (milk)
# 5  0.238368  (mineral water)
# 6  0.174110      (spaghetti)

# %% [markdown]
# 17% of transactions contain eggs, spaghetti and french fries.

# %%
frequent_itemsets=apriori(df1, min_support=0.05, use_colnames=True)
frequent_itemsets
# Out:
#      support                    itemsets
# 0   0.087188                   (burgers)
# 1   0.081056                      (cake)
# 2   0.059992                   (chicken)
# 3   0.163845                 (chocolate)
# 4   0.080389                   (cookies)
# 5   0.051060               (cooking oil)
# 6   0.179709                      (eggs)
# 7   0.079323                  (escalope)
# 8   0.170911              (french fries)
# 9   0.063325           (frozen smoothie)
# 10  0.095321         (frozen vegetables)
# 11  0.052393             (grated cheese)
# 12  0.132116                 (green tea)
# 13  0.098254               (ground beef)
# 14  0.076523            (low fat yogurt)
# 15  0.129583                      (milk)
# 16  0.238368             (mineral water)
# 17  0.065858                 (olive oil)
# 18  0.095054                  (pancakes)
# 19  0.071457                    (shrimp)
# 20  0.050527                      (soup)
# 21  0.174110                 (spaghetti)
# ...

# %%
from mlxtend.frequent_patterns import association_rules 
association_rules(frequent_itemsets,metric="confidence",min_threshold=0.1)
# Out:
#        antecedents      consequents  antecedent support  consequent support  \
# 0      (chocolate)  (mineral water)            0.163845            0.238368
# 1  (mineral water)      (chocolate)            0.238368            0.163845
# 2           (eggs)  (mineral water)            0.179709            0.238368
# 3  (mineral water)           (eggs)            0.238368            0.179709
# 4      (spaghetti)  (mineral water)            0.174110            0.238368
# 5  (mineral water)      (spaghetti)            0.238368            0.174110
#
#     support  confidence      lift  leverage  conviction
# 0  0.052660    0.321400  1.348332  0.013604    1.122357
# 1  0.052660    0.220917  1.348332  0.013604    1.073256
# 2  0.050927    0.283383  1.188845  0.008090    1.062815
# 3  0.050927    0.213647  1.188845  0.008090    1.043158
# 4  0.059725    0.343032  1.439085  0.018223    1.159314
# 5  0.059725    0.250559  1.439085  0.018223    1.102008

# %% [markdown]
# 32%, 28% and 34% respectively of the transactions that contain chocolate, eggs and spaghetti respectively have mineral water. When buying mineral water, the frequency of buying the other items decreases.

# %%
association_rules(frequent_itemsets,metric="lift",min_threshold=1.25)
# Out:
#        antecedents      consequents  antecedent support  consequent support  \
# 0      (chocolate)  (mineral water)            0.163845            0.238368
# 1  (mineral water)      (chocolate)            0.238368            0.163845
# 2      (spaghetti)  (mineral water)            0.174110            0.238368
# 3  (mineral water)      (spaghetti)            0.238368            0.174110
#
#     support  confidence      lift  leverage  conviction
# 0  0.052660    0.321400  1.348332  0.013604    1.122357
# 1  0.052660    0.220917  1.348332  0.013604    1.073256
# 2  0.059725    0.343032  1.439085  0.018223    1.159314
# 3  0.059725    0.250559  1.439085  0.018223    1.102008

# %% [markdown]
# It's rather to buy mineral water and chocolate together than chocolate alone (same for spaghetti).
# For this dataset and the samples taken for this market, mineral water is the most frequent product bought by almost 23% of the customers and some of them also buy chocolate or spaghetti.
