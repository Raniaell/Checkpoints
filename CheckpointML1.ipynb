# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn import metrics

# %%
df = pd.read_csv('C:/Users/rania/OneDrive/Bureau/kc_house_data.csv', encoding= "ISO-8859-1")
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
plt.title("Histogram of price")
plt.xlabel("price")
df['price'].plot.hist()
# Out:
# <AxesSubplot:title={'center':'Histogram of price'}, xlabel='price', ylabel='Frequency'>

# %%
plt.title("Histogram of the number of bedrooms")
plt.xlabel("bedrooms")
df['bedrooms'].plot.hist()
# Out:
# <AxesSubplot:title={'center':'Histogram of the number of bedrooms'}, xlabel='bedrooms', ylabel='Frequency'>

# %%
plt.title("Histogram of grade")
plt.xlabel("grade")
df['grade'].plot.hist()
# Out:
# <AxesSubplot:title={'center':'Histogram of grade'}, xlabel='grade', ylabel='Frequency'>

# %%
plt.title("Histogram of the number of bathrooms")
plt.xlabel("bathrooms")
df['bathrooms'].plot.hist()
# Out:
# <AxesSubplot:title={'center':'Histogram of the number of bathrooms'}, xlabel='bathrooms', ylabel='Frequency'>

# %%
plt.title("Histogram of the condition")
plt.xlabel("condition")
df['condition'].plot.hist()
# Out:
# <AxesSubplot:title={'center':'Histogram of the condition'}, xlabel='condition', ylabel='Frequency'>

# %%
plt.title("Histogram of the number of floors")
plt.xlabel("floors")
df['floors'].plot.hist()
# Out:
# <AxesSubplot:title={'center':'Histogram of the number of floors'}, xlabel='floors', ylabel='Frequency'>

# %%
plt.title("Histogram of sqft_above")
plt.xlabel("sqft_above")
df['sqft_above'].plot.hist()
# Out:
# <AxesSubplot:title={'center':'Histogram of sqft_above'}, xlabel='sqft_above', ylabel='Frequency'>

# %%
plt.title("Histogram of sqft_living")
plt.xlabel("sqft_living")
df['sqft_living'].plot.hist()
# Out:
# <AxesSubplot:title={'center':'Histogram of sqft_living'}, xlabel='sqft_living', ylabel='Frequency'>

# %%
plt.title("Histogram of sqft_lot")
plt.xlabel("sqft_lot")
df['sqft_lot'].plot.hist()
# Out:
# <AxesSubplot:title={'center':'Histogram of sqft_lot'}, xlabel='sqft_lot', ylabel='Frequency'>

# %%
plt.title("Histogram of sqft_living15")
plt.xlabel("sqft_living15")
df['sqft_living15'].plot.hist()
# Out:
# <AxesSubplot:title={'center':'Histogram of sqft_living15'}, xlabel='sqft_living15', ylabel='Frequency'>

# %%
plt.title("Histogram of sqft_lot15")
plt.xlabel("sqft_lot15")
df['sqft_lot15'].plot.hist()
# Out:
# <AxesSubplot:title={'center':'Histogram of sqft_lot15'}, xlabel='sqft_lot15', ylabel='Frequency'>

# %%
import matplotlib.pyplot as plt 
import seaborn as sns
def plot_correlation_map( df ):
    corr = df.corr()
    plt=__import__("matplotlib.pyplot")
    s,ax= plt.pyplot.subplots(figsize =( 18 , 15 ) )
    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )
    s = sns.heatmap(corr, cmap = cmap, square=True, cbar_kws={'shrink' : .9}, ax=ax, annot = True, annot_kws = {'fontsize': 12 })

# %%
plot_correlation_map(df)

# %% [raw]
# The most important features for predicting the house prices are price, grade, sqft_living, sqft_above, sqft_lot, sqft_living15, sqft_lot15, bathrooms and bedrooms due to the high correlation between these features.

# %%
x=df["sqft_living"].values[:,np.newaxis]
y=df["price"].values

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.35,random_state=40) #splitting data with test size of 35%

model=LinearRegression()   #build linear regression model
model.fit(x_train,y_train)  #fitting the training data
predicted=model.predict(x_test) #testing our model’s performance


print("MSE", mean_squared_error(y_test,predicted))
print("R squared", metrics.r2_score(y_test,predicted))
# Out:
# MSE 62902408306.86502
# R squared 0.4996528488387417

# %%
plt.scatter(x,y,color="r")
plt.title("Linear Regression")
plt.ylabel("price")
plt.xlabel("sqft_living")
plt.plot(x,model.predict(x),color="k")
plt.show()

# %%
x=df["sqft_living"].values[:,np.newaxis]
y=df["sqft_above"].values

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.35,random_state=40) #splitting data with test size of 35%

model=LinearRegression()   #build linear regression model
model.fit(x_train,y_train)  #fitting the training data
predicted=model.predict(x_test) #testing our model’s performance


print("MSE", mean_squared_error(y_test,predicted))
print("R squared", metrics.r2_score(y_test,predicted))
# Out:
# MSE 158675.285563018
# R squared 0.76867117371064

# %%
plt.scatter(x,y,color="r")
plt.title("Linear Regression")
plt.ylabel("sqft_above")
plt.xlabel("sqft_living")
plt.plot(x,model.predict(x),color="k")
plt.show()

# %%
x=df["sqft_living"].values[:,np.newaxis]
y=df["grade"].values

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.35,random_state=40) #splitting data with test size of 35%

model=LinearRegression()   #build linear regression model
model.fit(x_train,y_train)  #fitting the training data
predicted=model.predict(x_test) #testing our model’s performance


print("MSE", mean_squared_error(y_test,predicted))
print("R squared", metrics.r2_score(y_test,predicted))
# Out:
# MSE 0.5736559605838965
# R squared 0.5873628725791618

# %%
plt.scatter(x,y,color="b")
plt.title("Linear Regression")
plt.ylabel("sqft_above")
plt.xlabel("sqft_living")
plt.plot(x,model.predict(x),color="k")
plt.show()

# %%
x=df["sqft_living"].values[:,np.newaxis]
y=df["sqft_living15"].values

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.35,random_state=40) #splitting data with test size of 35%

model=LinearRegression()   #build linear regression model
model.fit(x_train,y_train)  #fitting the training data
predicted=model.predict(x_test) #testing our model’s performance


print("MSE", mean_squared_error(y_test,predicted))
print("R squared", metrics.r2_score(y_test,predicted))
# Out:
# MSE 188907.61168477195
# R squared 0.6007899812644217

# %%
plt.scatter(x,y,color="b")
plt.title("Linear Regression")
plt.ylabel("sqft_living15")
plt.xlabel("sqft_living")
plt.plot(x,model.predict(x),color="k")
plt.show()

# %%
model.coef_
# Out:
# array([0.55418058])

# %%
model.intercept_
# Out:
# 834.5751647831544

# %%
x=df["sqft_living"].values[:,np.newaxis]
y=df["sqft_above"].values

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.35,random_state=40) #splitting data with test size of 35%

model=LinearRegression()   #build linear regression model
model.fit(x_train,y_train)  #fitting the training data
predicted=model.predict(x_test) #testing our model’s performance


print("MSE", mean_squared_error(y_test,predicted))
print("R squared", metrics.r2_score(y_test,predicted))
# Out:
# MSE 158675.285563018
# R squared 0.76867117371064

# %%
plt.scatter(x,y,color="r")
plt.title("Linear Regression")
plt.ylabel("sqft_above")
plt.xlabel("sqft_living")
plt.plot(x,model.predict(x),color="k")
plt.show()

# %%
model.coef_
model.intercept_

# %%
#extract x and y from our data
x=df[["sqft_above","sqft_living"]]  #we have more than one input
y=df["price"].values
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.35,random_state=40) #splitting data with test size of 35%

model=LinearRegression() #build linear regression model
model.fit(x_train,y_train) #fitting the training data
predicted=model.predict(x_test) #testing our model’s performance

print("MSE", mean_squared_error(y_test,predicted))
print("R squared", metrics.r2_score(y_test,predicted))
# Out:
# MSE 62831668851.97097
# R squared 0.5002155345241335

# %%
x= df[["sqft_living", "sqft_above"]]
y= df["price"].values

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.35, random_state=40)  #splitting data
lg=LinearRegression()
poly=PolynomialFeatures(degree=3)

x_train_fit = poly.fit_transform(x_train) #transforming our input data
lg.fit(x_train_fit, y_train)
x_test_ = poly.fit_transform(x_test)
predicted = lg.predict(x_test_)

print("MSE: ", metrics.mean_squared_error(y_test, predicted))
print("R squared: ", metrics.r2_score(y_test,predicted))
# Out:
# MSE:  57232313793.913055
# R squared:  0.5447547092083863

# %%
x= df["sqft_living"].values.reshape(-1,1)
y= df["price"].values
poly = PolynomialFeatures(degree = 2) 
x_poly = poly.fit_transform(x) 
poly.fit(x_poly, y) 
lg=LinearRegression()
lg.fit(x_poly, y) 

plt.scatter(x, y, color="r")
plt.title("Linear regression")
plt.ylabel("sqft_living")
plt.xlabel("price")
plt.plot(x, lg.predict(poly.fit_transform(x)), color="k")
