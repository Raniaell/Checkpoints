# %% [markdown]
# Checkpoint Data Visualization (Rania Elloumi)

# %% [markdown]
# 1. Preprocessing phase
#
# After importing the dataset using Pandas start by showing the head of the dataset then some general information about the data columns and values.
#
# As a next step, apply what you have learned in the course to preprocess your data: find missing information and replace it with the appropriate values.
#
# Verify that your data is ready to be treated.

# %%
import pandas as pd 
df = pd.read_csv('C:/Users/rania/Downloads/titanic-passengers.csv', encoding= "ISO-8859-1", sep=";")
df.head() #show the first lines of the dataset
# Out:
#    PassengerId Survived  Pclass                                         Name  \
# 0          343       No       2                   Collander, Mr. Erik Gustaf
# 1           76       No       3                      Moen, Mr. Sigurd Hansen
# 2          641       No       3                       Jensen, Mr. Hans Peder
# 3          568       No       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672       No       1                       Davidson, Mr. Thornton
#
#       Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked
# 0    male  28.0      0      0      248740  13.0000    NaN        S
# 1    male  25.0      0      0      348123   7.6500  F G73        S
# 2    male  20.0      0      0      350050   7.8542    NaN        S
# 3  female  29.0      0      4      349909  21.0750    NaN        S
# 4    male  31.0      1      0  F.C. 12750  52.0000    B71        S

# %%
df.isnull().sum() #this function will allow us to see the total number of missing values
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
print(df['Cabin'].head())
print(df['Cabin'].head().isnull()) #indicate the place of missing values in each variable
# Out:
# 0      NaN
# 1    F G73
# 2      NaN
# 3      NaN
# 4      B71
# Name: Cabin, dtype: object
# 0     True
# 1    False
# 2     True
# 3     True
# 4    False
# Name: Cabin, dtype: bool

# %%
print(df['Age'].tail())
print(df['Age'].tail().isnull())
# Out:
# 886    14.0
# 887    22.0
# 888    30.0
# 889     NaN
# 890    19.0
# Name: Age, dtype: float64
# 886    False
# 887    False
# 888    False
# 889     True
# 890    False
# Name: Age, dtype: bool

# %%
print(df['Embarked'].head())
print(df['Embarked'].head().isnull())
# Out:
# 0    S
# 1    S
# 2    S
# 3    S
# 4    S
# Name: Embarked, dtype: object
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Embarked, dtype: bool

# %%
df['Age'].fillna( df['Age'].mode()[0], inplace=True )
df.head() #replace the missing values of the column age with the fillna function using mode
# Out:
#    PassengerId Survived  Pclass                                         Name  \
# 0          343       No       2                   Collander, Mr. Erik Gustaf
# 1           76       No       3                      Moen, Mr. Sigurd Hansen
# 2          641       No       3                       Jensen, Mr. Hans Peder
# 3          568       No       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672       No       1                       Davidson, Mr. Thornton
#
#       Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked
# 0    male  28.0      0      0      248740  13.0000    NaN        S
# 1    male  25.0      0      0      348123   7.6500  F G73        S
# 2    male  20.0      0      0      350050   7.8542    NaN        S
# 3  female  29.0      0      4      349909  21.0750    NaN        S
# 4    male  31.0      1      0  F.C. 12750  52.0000    B71        S

# %%
noe= len(df["Cabin"])
print("noe:", noe)
print(df["Cabin"].value_counts())
df["Cabin"].fillna('G6', inplace=True) #replace the categorical missing values of Cabin with 'G6' (most frequent one)
df.head()
# Out:
# noe: 891
# G6             4
# B96 B98        4
# C23 C25 C27    4
# F33            3
# D              3
#               ..
# C91            1
# D45            1
# F G63          1
# A34            1
# E63            1
# Name: Cabin, Length: 147, dtype: int64
#    PassengerId Survived  Pclass                                         Name  \
# 0          343       No       2                   Collander, Mr. Erik Gustaf
# 1           76       No       3                      Moen, Mr. Sigurd Hansen
# 2          641       No       3                       Jensen, Mr. Hans Peder
# 3          568       No       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672       No       1                       Davidson, Mr. Thornton
#
#       Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked
# 0    male  28.0      0      0      248740  13.0000     G6        S
# 1    male  25.0      0      0      348123   7.6500  F G73        S
# ...

# %%
noe_= len(df["Embarked"])
print("number of elements:", noe_)
print(df["Embarked"].value_counts())
df["Embarked"].fillna('S', inplace=True) #replacing the categorical missing values of Embarked with the most used one 'S'
df.tail()
# Out:
# number of elements: 891
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64
#      PassengerId Survived  Pclass  \
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 886                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 887                              Sirayanian, Mr. Orsen    male  22.0      0
# 888                                Cacic, Miss. Marija  female  30.0      0
# 889                   Petroff, Mr. Pastcho ("Pentcho")    male  24.0      0
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...  female  19.0      0
#
#      Parch  Ticket     Fare Cabin Embarked
# 886      0  237736  30.0708    G6        C
# 887      0    2669   7.2292    G6        C
# 888      0  315084   8.6625    G6        S
# ...

# %%
df.isnull().sum() #After preprocessing the data we should verif that there's no more missing value in the dataset! Now the data is ready for the visualization phase
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %% [markdown]
# 2. Visualization phase:
#
# Start by studying the distribution of the most important features based on your understanding of the dataset and the problem.
#
# Visualize the correlation between Sex and Age in a plot of your choosing. The visualized plot should give us obvious deductions concerning the importance of age and sex in the survival of the individuals.
#
# Pick two other features and study their impact on the survival of the individuals.
#
# Have a look at this function:
#
# def plot_correlation_map( df ):
#
#     corr = df.corr()
#
#     s , ax = plt.subplots( figsize =( 12 , 10 ) )
#
#     cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )
#
#     s = sns.heatmap(
#
#         corr,
#
#         cmap = cmap,
#
#         square=True,
#
#         cbar_kws={ 'shrink' : .9 },
#
#         ax=ax,
#
#         annot = True,
#
#         annot_kws = { 'fontsize' : 12 }
#
#         )
#
# Try running the function, analyze what it does exactly and its utilities. Write a paragraph describing your analysis (the paragraph should be in English).
#
# Use the groupby function combined with the mean() to view the relation between Pclass and survived
#
# As a final step, try to drop the useless columns (such as Names).
#
# We dropped the column Names because we evaluated it to be useless. But that's ultimately not the case because we can create a very useful feature from Names.
#
# Your task now is to create a new column called Title which contains the appropriate Title for each individual. Hint: Extract the title from the column Names.
#
# Visualize the correlation between Title and other features(e.g Sex, Fare, Age).
#
# As you have seen, there are a lot of titles which makes the feature very impractical. Let's try to group these titles into more useful ones.
#
# Hint: Use the following dictionary
#
# Title_Dictionary = {
#
#                     "Capt":       "Officer",
#
#                     "Col":        "Officer",
#
#                     "Major":      "Officer",
#
#                       "Dr":         "Officer",
#
#                     "Rev":        "Officer”,
#
#                     "Jonkheer":   "Royalty",
#
#                     "Don":        "Royalty",
#
#                     "Sir" :       "Royalty",
#
#                    "Lady" :      "Royalty"
#
#                   "the Countess": "Royalty",
#
#                     "Dona":       "Royalty”,
#
#                     "Mme":        "Miss",
#
#                     "Mlle":       "Miss",
#
#                     "Miss" :      "Miss",
#
#                     "Ms":         "Mrs",
#
#                     "Mr" :        "Mrs",
#
#                     "Mrs" :       "Mrs
#
#                     "Master" :    "Master"
#
#                     }
#
# Let's visualize the same correlations using these new titles now.
#
# Finally, use the Parch and the SibSp columns to create a more useful feature, let's call it FamilySize.
#
# Use what you have learned so far to conclude if this feature is useful or not.

# %%
#Get some information about the type of the different features to distinguish between categorical and numerical data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    object
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        891 non-null    object
#  11  Embarked     891 non-null    object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 83.7+ KB

# %% [markdown]
# Visualize the most important features

# %%
import matplotlib.pyplot as plt 
import seaborn as sns
plt.title("Histogram of different ages") #plot the histrogram of ages
plt.xlabel("Age")
sns.distplot(df["Age"], bins=10, hist=True, kde= True, color="red")
# Out:
# C:\Users\rania\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:title={'center':'Histogram of different ages'}, xlabel='Age', ylabel='Density'>

# %%
sns.countplot(x='Sex', data = df)
plt.xticks(rotation=45)
# Out:
# (array([0, 1]), [Text(0, 0, 'male'), Text(1, 0, 'female')])

# %%
#Visualize the number of number of people who survived or not
sns.countplot(x='Survived', data = df)
plt.xticks(rotation=0)
# Out:
# (array([0, 1]), [Text(0, 0, 'No'), Text(1, 0, 'Yes')])

# %%
#visualize a categorical feature
sns.countplot(x='Pclass', data = df)
plt.xticks(rotation=0)
# Out:
# (array([0, 1, 2]), [Text(0, 0, '1'), Text(1, 0, '2'), Text(2, 0, '3')])

# %%
#Visualize a categorical feature
sns.countplot(x='Embarked', data = df)
plt.xticks(rotation=0)
# Out:
# (array([0, 1, 2]), [Text(0, 0, 'S'), Text(1, 0, 'C'), Text(2, 0, 'Q')])

# %%
#Visualize SibSp with seaborn
plt.title("Histogram of Siblings and Spouses")
plt.xlabel("SibSp")
sns.distplot(df["SibSp"], hist=True, kde= True)
# Out:
# C:\Users\rania\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:title={'center':'Histogram of Siblings and Spouses'}, xlabel='SibSp', ylabel='Density'>

# %%
#Visualize the Parch histogram with seaborn
plt.title("Histogram of Parents and Children")
plt.xlabel("Parch")
sns.distplot(df["Parch"], hist=True, kde= True)
# Out:
# C:\Users\rania\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:title={'center':'Histogram of Parents and Children'}, xlabel='Parch', ylabel='Density'>

# %%
plt.title("Histogram of different ticket prices") #plot the histrogram of ages
plt.xlabel("Fare")
sns.distplot(df["Fare"], hist=True, kde= True)
# Out:
# C:\Users\rania\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:title={'center':'Histogram of different ticket prices'}, xlabel='Fare', ylabel='Density'>

# %% [markdown]
# Most of the ticket prices were approximately under 50 pounds.

# %% [raw]
# #correlation between Sex and Age

# %%
sns.boxplot(x='Sex', y='Age', data = df)
plt.title("correlation between sex and age")
# Out:
# Text(0.5, 1.0, 'correlation between sex and age')

# %% [markdown]
# For the age distribution, male and female have approximately the same ages however we can notice a lot of outliers especially for male (under the age of 10 and above 50)

# %%
sns.boxplot(x='Survived', y='Age', data = df)
plt.title("correlation between survival and age")
# Out:
# Text(0.5, 1.0, 'correlation between survival and age')

# %%
sns.countplot(data= df, x='Sex', hue='Survived')
plt.title("Survival and Sex")
# Out:
# Text(0.5, 1.0, 'Survival and Sex')

# %% [markdown]
# Most of the people who survived are women

# %%
cor= sns.FacetGrid(df, row='Sex', col='Survived')
cor.map(plt.hist, 'Age')

# %% [markdown]
# This is another method to visualize the correlation between sex and age and to see their relation to the survival. We can notice that most of the people who survived are women and their is above 20 and under 30.

# %%
#The first feature is the Pclass
sns.countplot(data= df, x='Survived', hue='Pclass')
plt.title("correlation between survival and the class of a ticket")
# Out:
# Text(0.5, 1.0, 'correlation between survival and the class of a ticket')

# %% [markdown]
# In this graph, the people are more likely to die when they are sitting in the 3rd Class. However, those of who are sitting in the first class are more likely to survive.

# %%
#Boxplot Survived and Fare
sns.boxplot(data= df, x='Survived', y='Fare')
plt.title("correlation between survival and the price of a ticket")
# Out:
# Text(0.5, 1.0, 'correlation between survival and the price of a ticket')

# %%
#The second feature chosen is "Embarked"
sns.countplot(data= df, x='Embarked', hue='Survived')
plt.title("Correlation between survival and port of embarkation")
# Out:
# Text(0.5, 1.0, 'Correlation between survival and port of embarkation')

# %% [markdown]
# Most of the people embarked at the port S. However, people who managed the most to survive are located at the the Port C.

# %%
#The correlation function
import matplotlib.pyplot as plt 
import seaborn as sns

def plot_correlation_map( df ):
    corr = df.corr()
    plt=__import__("matplotlib.pyplot")
    s,ax= plt.pyplot.subplots(figsize =( 12 , 10 ) )
    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )
    s = sns.heatmap(corr, cmap = cmap, square=True, cbar_kws={'shrink' : .9}, ax=ax, annot = True, annot_kws = {'fontsize': 12 })

# %%
plot_correlation_map(df)

# %% [markdown]
# This fuction is used as a tool to correlate between different features in a dataset. It is represented as a correlation matrix. It allows us to visualize the degree of correlation that exists between different variables for example the correlation between (Fare, Pclass) has the lowest degree and the value is -0.55 whereas the same features (Age,Age) have the highest degree of correlation which is 1. I think this function will allow us to reduce the number of features and to avoid the useless columns.
# This is a dimensionality reduction and it is used to improve the runtime and effectiveness of this model.

# %%
#groupby function for "Survived" and "Pclass"
df['Survived'].groupby(df['Pclass']).value_counts()
# Out:
# Pclass  Survived
# 1       Yes         136
#         No           80
# 2       No           97
#         Yes          87
# 3       No          372
#         Yes         119
# Name: Survived, dtype: int64

# %%
#Convert 'Survived' categorical feature into numerical in order to calculate the mean
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
df['Survived']=encoder.fit_transform(df['Survived'])
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            343         0       2
# 1             76         0       3
# 2            641         0       3
# 3            568         0       3
# 4            672         0       1
# ..           ...       ...     ...
# 886           10         1       2
# 887           61         0       3
# 888          535         0       3
# 889          102         0       3
# 890          428         1       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Calculate the mean between Survived and Pclass using the function groupby
df['Survived'].groupby(df['Pclass']).mean()
# Out:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %% [markdown]
# According to the results, most of the people who survived are sitting in the 1st class.

# %%
#Drop the column name
df.drop(['Name'], axis=1)
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch      Ticket  \
# 0            343         0       2    male  28.0      0      0      248740
# 1             76         0       3    male  25.0      0      0      348123
# 2            641         0       3    male  20.0      0      0      350050
# 3            568         0       3  female  29.0      0      4      349909
# 4            672         0       1    male  31.0      1      0  F.C. 12750
# ..           ...       ...     ...     ...   ...    ...    ...         ...
# 886           10         1       2  female  14.0      1      0      237736
# 887           61         0       3    male  22.0      0      0        2669
# 888          535         0       3  female  30.0      0      0      315084
# 889          102         0       3    male  24.0      0      0      349215
# 890          428         1       2  female  19.0      0      0      250655
#
#         Fare  Cabin Embarked
# 0    13.0000     G6        S
# ...

# %%
#Creating a new column named 'Title'
df['Title'] = df.Name.str.extract(' ([A-Za-z]+)\.', expand=False)

# %%
#Show the number of male and female for each title depending on sex
pd.crosstab(df['Title'], df['Sex'])
# Out:
# Sex       female  male
# Title
# Capt           0     1
# Col            0     2
# Countess       1     0
# Don            0     1
# Dr             1     6
# Jonkheer       0     1
# Lady           1     0
# Major          0     2
# Master         0    40
# Miss         182     0
# Mlle           2     0
# Mme            1     0
# Mr             0   517
# Mrs          125     0
# Ms             1     0
# Rev            0     6
# Sir            0     1

# %%
#Replacing the old titles by more useful ones using this dictionary
d={"Title" : {"Capt":"Officer", "Col": "Officer", "Countness":"Officer", "Don": "Royalty", "Dr": "Officer", "Jonkheer":"Royalty", "Lady": "Royalty", "Major": "Officer", "Master": "Master", "Miss": "Miss", "Mlle": "Miss", "Mme": "Miss", "Mr": "Mr", "Mrs": "Mrs", "Ms": "Mrs", "Rev": "Officer", "Sir":"Royalty" }}
df.replace(d, inplace=True)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            343         0       2
# 1             76         0       3
# 2            641         0       3
# 3            568         0       3
# 4            672         0       1
# ..           ...       ...     ...
# 886           10         1       2
# 887           61         0       3
# 888          535         0       3
# 889          102         0       3
# 890          428         1       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Title'].value_counts()
# Out:
# Mr          517
# Miss        185
# Mrs         126
# Master       40
# Officer      18
# Royalty       4
# Countess      1
# Name: Title, dtype: int64

# %%
sns.countplot(data= df, x='Survived', hue='Title')
plt.title("correlation between survival and the title")
# Out:
# Text(0.5, 1.0, 'correlation between survival and the title')

# %%
#Age and Title
sns.boxplot(data=df, x='Title', y='Age')
plt.title("Boxplot of Title depending on Age")
# Out:
# Text(0.5, 1.0, 'Boxplot of Title depending on Age')

# %% [markdown]
# Officers and Royalty were the oldest on Titanic whereas Master were the youngest category.

# %%
sns.boxplot(data=df, x='Title', y='Fare')
plt.title("Boxplot of Title depending on Fare")
# Out:
# Text(0.5, 1.0, 'Boxplot of Title depending on Fare')

# %%
#Title and Sex
sns.countplot(data= df, x='Title', hue='Sex')
plt.title("Title depending on Sex")
# Out:
# Text(0.5, 1.0, 'Title depending on Sex')

# %%
cor= sns.FacetGrid(df, row='Sex', col='Survived')
plt.xticks(rotation=45)
cor.map(plt.hist, 'Title')

# %%
#Create new column familySize by adding Parch and SibSp
df['FamilySize'] = df['SibSp'] + df['Parch'] 
df['FamilySize'].describe()
# Out:
# count    891.000000
# mean       0.904602
# std        1.613459
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max       10.000000
# Name: FamilySize, dtype: float64

# %%
sns.boxplot(data=df, x='Title', y='FamilySize')
plt.title("Correlation between Title and FamilySize")
# Out:
# Text(0.5, 1.0, 'Correlation between Title and FamilySize')

# %% [markdown]
# Most of the men travelled alone and master are the ones who travelled with their families.

# %%
#Correlation between survival and the number of family members
sns.countplot(data= df, x='Survived', hue='FamilySize')
plt.title("correlation between survival and the familysize")
# Out:
# Text(0.5, 1.0, 'correlation between survival and the familysize')

# %% [markdown]
# For those who are traveling alone, they have bigger chance to survive and for those who are traveling with their families (especially big families with more than 3 members) they have bigger chance to die.

# %%
plot_correlation_map(df)

# %% [markdown]
# For the new feature we created 'FamilySize', it has no correlation with the other features except for Parch and Sibsp. So we can use it instead of these two to reduce useless columns and improve the effectiveness of the model.
