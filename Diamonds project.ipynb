# %% [markdown]
# ## In this machine learning project, we will try to predict diamond's price based on different features.

# %% [markdown]
# #### Data Preparation

# %%
#importing the data
import pandas as pd 
data = pd.read_csv('C:/Users/rania/OneDrive/Bureau/GoMyCode_AI_Training/diamonds.csv', sep=',')
data
# Out:
#        carat           cut color clarity  depth  table   price   'x'   'y'  \
# 0       0.23      b'Ideal'  b'E'  b'SI2'   61.5   55.0   326.0  3.95  3.98
# 1       0.21    b'Premium'  b'E'  b'SI1'   59.8   61.0   326.0  3.89  3.84
# 2       0.23       b'Good'  b'E'  b'VS1'   56.9   65.0   327.0  4.05  4.07
# 3       0.29    b'Premium'  b'I'  b'VS2'   62.4   58.0   334.0  4.20  4.23
# 4       0.31       b'Good'  b'J'  b'SI2'   63.3   58.0   335.0  4.34  4.35
# ...      ...           ...   ...     ...    ...    ...     ...   ...   ...
# 53935   0.72      b'Ideal'  b'D'  b'SI1'   60.8   57.0  2757.0  5.75  5.76
# 53936   0.72       b'Good'  b'D'  b'SI1'   63.1   55.0  2757.0  5.69  5.75
# 53937   0.70  b'Very Good'  b'D'  b'SI1'   62.8   60.0  2757.0  5.66  5.68
# 53938   0.86    b'Premium'  b'H'  b'SI2'   61.0   58.0  2757.0  6.15  6.12
# 53939   0.75      b'Ideal'  b'D'  b'SI2'   62.2   55.0  2757.0  5.83  5.87
#
#         'z'
# 0      2.43
# 1      2.31
# 2      2.31
# 3      2.63
# ...

# %%
data.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', ''x'',
#        ''y'', ''z''],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  object
#  2   color    53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  float64
#  7   'x'      53940 non-null  float64
#  8   'y'      53940 non-null  float64
#  9   'z'      53940 non-null  float64
# dtypes: float64(7), object(3)
# memory usage: 4.1+ MB

# %%
data.describe()
# Out:
#               carat         depth         table         price           'x'  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                 'y'           'z'
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
#Verify missing values
data.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# 'x'        0
# 'y'        0
# 'z'        0
# dtype: int64

# %%
#Visualize the most frequent value in each column
for col in data: 
    print("The column is :", col)
    print(data[col].value_counts())
    print('-------------------------------')
# Out:
# The column is : carat
# 0.30    2604
# 0.31    2249
# 1.01    2242
# 0.70    1981
# 0.32    1840
#         ...
# 3.02       1
# 3.65       1
# 3.50       1
# 3.22       1
# 3.11       1
# Name: carat, Length: 273, dtype: int64
# -------------------------------
# The column is : cut
# b'Ideal'        21551
# b'Premium'      13791
# b'Very Good'    12082
# b'Good'          4906
# b'Fair'          1610
# Name: cut, dtype: int64
# -------------------------------
# The column is : color
# b'G'    11292
# b'E'     9797
# b'F'     9542
# b'H'     8304
# b'D'     6775
# b'I'     5422
# b'J'     2808
# Name: color, dtype: int64
# -------------------------------
# The column is : clarity
# b'SI1'     13065
# b'VS2'     12258
# b'SI2'      9194
# b'VS1'      8171
# b'VVS2'     5066
# b'VVS1'     3655
# b'IF'       1790
# b'I1'        741
# Name: clarity, dtype: int64
# -------------------------------
# The column is : depth
# 62.0    2239
# 61.9    2163
# 61.8    2077
# 62.2    2039
# ...

# %% [markdown]
# #### Data Visualization

# %%
import matplotlib.pyplot as plt
Lst=['cut','color','clarity']
for n in Lst: 
    data[n].value_counts().plot.bar(rot=0, color='blue')
    plt.title(n)
    plt.show()

# %%
import matplotlib.pyplot as plt
L=["carat","depth","table","price","'x'","'y'","'z'"]
for i in L: 
    plt.xlabel(i)
    data[i].plot.hist()
    plt.show()

# %%
import seaborn as sns
sns.scatterplot(x='carat', y='price', data=data)
plt.title('Correlation between price and carat')
# Out:
# Text(0.5, 1.0, 'Correlation between price and carat')

# %%
sns.lineplot(x= 'carat', y= 'price', data= data)
plt.title('Correlation between price and carat')
plt.show()

# %% [markdown]
# An increase in carat measure will induce to the increase of diamond price.
# Carat is an important feature for estimating a diamond's price.

# %%
sns.scatterplot(x="'x'", y='price', data=data)
plt.title('Correlation between price and x')
# Out:
# Text(0.5, 1.0, 'Correlation between price and x')

# %%
sns.scatterplot(x="'y'", y='price', data=data)
plt.title('Correlation between price and y')
# Out:
# Text(0.5, 1.0, 'Correlation between price and y')

# %%
sns.scatterplot(x="'z'", y='price', data=data)
plt.title('Correlation between price and z')
# Out:
# Text(0.5, 1.0, 'Correlation between price and z')

# %%
sns.scatterplot(x='price', y='table', data=data)
plt.title('Correlation between price and table')
# Out:
# Text(0.5, 1.0, 'Correlation between price and table')

# %%
sns.scatterplot(x='price', y='depth', data=data)
plt.title('Correlation between price and depth')
# Out:
# Text(0.5, 1.0, 'Correlation between price and depth')

# %% [markdown]
# Table and depth don't show a relationship with the variation of the diamond price.

# %%
sns.scatterplot(x='cut', y='price', data=data)
plt.title('Correlation between price and cut')
# Out:
# Text(0.5, 1.0, 'Correlation between price and cut')

# %%
sns.lineplot(x= 'cut', y= 'price', data= data)
plt.title('Correlation between price and cut')
plt.show()

# %% [markdown]
# The most expensive expensive diamonds are with a Premium cut and the cheapest ones have an ideal cut. Thus, the cut of a diamond can determine its price.

# %%
sns.scatterplot(x='color', y='price', data=data)
plt.title('Correlation between price and color')
# Out:
# Text(0.5, 1.0, 'Correlation between price and color')

# %%
sns.lineplot(x= 'color', y= 'price', data= data)
plt.title('correlation between price and color of diamonds')
plt.show()

# %% [markdown]
# 'J' is the best color when talking about diamonds due to its exorbitant price. The colors 'E' and 'D' are classified are the worst ones since the diamond prices is very low. To conclude, color is also a mandatory feature to determine a diamond's price.

# %%
sns.scatterplot(x='clarity', y='price', data=data)
plt.title('Correlation between price and clarity')
# Out:
# Text(0.5, 1.0, 'Correlation between price and clarity')

# %%
sns.lineplot(x= 'clarity', y= 'price', data= data)
plt.title('Variation of Price vs clarity of diamonds')
plt.show()

# %% [markdown]
# The 'SI2' is a flawless diamond which explains the high price. The other clarity types contain imperfections and some inclusions with different degrees where the 'VVS2' is the worst one. To summarize, clarity is also an important parameter that affects the variation of a diamond's price.

# %%
import seaborn as sns
sns.scatterplot(data=data, x='carat', y='price', hue='cut')
plt.title("Variation of carat and price depending on the cut")
plt.show()

# %%
sns.scatterplot(data=data, x='carat', y='price', hue='clarity')
plt.title("Variation of carat and price depending on the clarity")
plt.show()

# %%
sns.scatterplot(data=data, x='carat', y='price', hue='color')
plt.title("Variation of carat and price depending on diamond's color")
plt.show()

# %%
sns.pairplot(data)

# %%
def plot_correlation_map( df ):

    corr = df.corr()

    s , ax = plt.subplots( figsize =( 12 , 10 ) )

    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )

    s = sns.heatmap(

        corr, 

        cmap = cmap,

        square=True, 

        cbar_kws={ 'shrink' : .9 }, 

        ax=ax, 

        annot = True, 

        annot_kws = { 'fontsize' : 12 }

        )


plot_correlation_map(data)

# %% [markdown]
# #### Overall, to determine a diamond's price we should take into consideration 4 important features: carat, x, y and z.

# %% [markdown]
# ### In this project, supervised learning is the best algorithm to work with because our data is already labeled (we know the ouput of each input).

# %% [markdown]
# #### Linear Regression

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn import metrics
#extract x and y
x=data["carat"].values[:,np.newaxis]
y=data["price"].values

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=40) #splitting data with test size of 20%

# %%
model=LinearRegression()   #build linear regression model
model.fit(x_train,y_train)  #fitting the training data
# Out:
# LinearRegression()

# %%
#Plot linear regression
plt.scatter(x,y,color="r")
plt.title("Linear Regression")
plt.ylabel("price")
plt.xlabel("carat")
plt.plot(x,model.predict(x),color="k")
plt.show()

# %%
predicted=model.predict(x_test) #testing our model’s performance
print("MSE", mean_squared_error(y_test,predicted))
print("R squared", metrics.r2_score(y_test,predicted))
# Out:
# MSE 2456952.3368221843
# R squared 0.8480118368870907

# %% [markdown]
# R squared indicates that the model is performing well with a value close to 85%.

# %%
features=["carat","'x'","'y'","'z'"]
for f in features:
    # extract x and y from our data
    y=data["price"].values
    x=data[f].values.reshape(-1,1)
    # splitting the data with test size = 20%
    x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.20, random_state=40)
    model=LinearRegression() # build linear regression
    model.fit(x_train, y_train) # fitting the training set
    predicted=model.predict(x_test) # test our model's performance
    print("Linear Regression with", f)
    print("MSE:", mean_squared_error(y_test, predicted))
    print("R squared:", metrics.r2_score(y_test, predicted))
    print("-----------------------------------------------------")
# Out:
# Linear Regression with carat
# MSE: 2456952.3368221843
# R squared: 0.8480118368870907
# -----------------------------------------------------
# Linear Regression with 'x'
# MSE: 3479586.679410105
# R squared: 0.7847512221259813
# -----------------------------------------------------
# Linear Regression with 'y'
# MSE: 3452345.0610451023
# R squared: 0.7864364007407504
# -----------------------------------------------------
# Linear Regression with 'z'
# MSE: 3656629.1486374117
# R squared: 0.7737992963244269
# -----------------------------------------------------

# %% [markdown]
# All the models are capable of well explaining the model's performance but the best feature is 'carat' with the best R squared and a lesser MSE value.

# %% [markdown]
# #### Multiple Regression

# %%
#select important features
L=data[["carat","'x'","'y'","'z'"]]
#extract x and y
x=L.iloc[:,1:]
y=data['price'].values
#split data
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=40)
model=LinearRegression() #build linear regression model
model.fit(x_train,y_train) #fitting the training data
predicted=model.predict(x_test) #testing our model’s performance

print("MSE", mean_squared_error(y_test,predicted))
print("R squared", metrics.r2_score(y_test,predicted))
# Out:
# MSE 3428118.1372846626
# R squared 0.786416470019257

# %% [markdown]
# In this case, multiple regression also indicates that the model is performing well.

# %% [markdown]
# #### Polynomial Regression

# %%
from sklearn.preprocessing import PolynomialFeatures
features=["carat","'x'","'y'","'z'"]
for f in features:
    # extract x and y from our data
    y=data["price"].values
    x=data[f].values.reshape(-1,1)
    # splitting the data with test size = 20%
    x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.20, random_state=40)
    lg=LinearRegression()
    print("\n")
    print("Polynomial Regression with",f,"\n")
    for i in range (2,11):
        poly=PolynomialFeatures(degree=i)
        # transformation to polynmial
        x_train_fit=poly.fit_transform(x_train)
        # fitting the model
        lg.fit(x_train_fit, y_train)
        # testing the model
        x_test_=poly.fit_transform(x_test)
        predicted=lg.predict(x_test_)
        print("Polynomial Degree :", i)
        print("MSE:", mean_squared_error(y_test, predicted))
        print("R squared:", metrics.r2_score(y_test, predicted))
# Out:
# Polynomial Regression with carat
#
# Polynomial Degree : 2
# MSE: 2437934.22573739
# R squared: 0.8491883056880255
# Polynomial Degree : 3
# MSE: 2204864.934744811
# R squared: 0.8636060755751724
# Polynomial Degree : 4
# MSE: 2123117.0431065247
# R squared: 0.8686630364702814
# Polynomial Degree : 5
# MSE: 2120098.2463207254
# R squared: 0.8688497805806202
# Polynomial Degree : 6
# MSE: 2107167.6625364358
# R squared: 0.869649672238223
# Polynomial Degree : 7
# MSE: 2109545.7567055337
# R squared: 0.8695025622764001
# Polynomial Degree : 8
# MSE: 2106980.8673598687
# R squared: 0.8696612274708334
# Polynomial Degree : 9
# MSE: 2119670.3759697187
# R squared: 0.8688762488306246
# Polynomial Degree : 10
# MSE: 2126794.4267185433
# R squared: 0.8684355518862804
#
#
# Polynomial Regression with 'x'
#
# Polynomial Degree : 2
# MSE: 2302008.0922843534
# R squared: 0.857596756691714
# Polynomial Degree : 3
# MSE: 2287219.7083644466
# R squared: 0.858511572691076
# Polynomial Degree : 4
# ...

# %% [markdown]
# Using the polynomial regression, there's an improvement in the model's performance. Also with the variation with the polynomial degree there are better R squared results for example for the feature Carat the best values of R squared and MSE are obtained for degree 8.

# %%
#Let's try to plot the polynomial regression of the feature 'carat'
from sklearn.preprocessing import PolynomialFeatures
x= data["carat"].values.reshape(-1,1)
y= data["price"].values
poly = PolynomialFeatures(degree = 8) 
x_poly = poly.fit_transform(x) 
poly.fit(x_poly, y) 
lg=LinearRegression()
lg.fit(x_poly, y) 

plt.scatter(x, y, color="r")
plt.title("Polynomial regression of price vs carat with polynomial degree 8 ")
plt.ylabel("price")
plt.xlabel("carat")
plt.plot(x, lg.predict(poly.fit_transform(x)), color="k")

# %% [markdown]
# Logistic regression can't be used  because we're trying to predict a numerical variable not a categorical one.

# %% [markdown]
# #### K nearest neighbor

# %%
data1=data 
data1=data1.drop('depth',axis=1)
data1=data1.drop('table',axis=1)

from sklearn.preprocessing import LabelEncoder
Cut= LabelEncoder()
Color= LabelEncoder()
Clarity= LabelEncoder()

data1['cut_n']= Cut.fit_transform(data1['cut'])
data1['color_n']= Color.fit_transform(data1['color'])
data1['clarity_n']= Clarity.fit_transform(data1['clarity'])
data1
# Out:
#        carat           cut color clarity   price   'x'   'y'   'z'  cut_n  \
# 0       0.23      b'Ideal'  b'E'  b'SI2'   326.0  3.95  3.98  2.43      2
# 1       0.21    b'Premium'  b'E'  b'SI1'   326.0  3.89  3.84  2.31      3
# 2       0.23       b'Good'  b'E'  b'VS1'   327.0  4.05  4.07  2.31      1
# 3       0.29    b'Premium'  b'I'  b'VS2'   334.0  4.20  4.23  2.63      3
# 4       0.31       b'Good'  b'J'  b'SI2'   335.0  4.34  4.35  2.75      1
# ...      ...           ...   ...     ...     ...   ...   ...   ...    ...
# 53935   0.72      b'Ideal'  b'D'  b'SI1'  2757.0  5.75  5.76  3.50      2
# 53936   0.72       b'Good'  b'D'  b'SI1'  2757.0  5.69  5.75  3.61      1
# 53937   0.70  b'Very Good'  b'D'  b'SI1'  2757.0  5.66  5.68  3.56      4
# 53938   0.86    b'Premium'  b'H'  b'SI2'  2757.0  6.15  6.12  3.74      3
# 53939   0.75      b'Ideal'  b'D'  b'SI2'  2757.0  5.83  5.87  3.64      2
#
#        color_n  clarity_n
# 0            1          3
# ...

# %% [markdown]
# Label encodings for: cut column is 1: b'good, 2: b'ideal, 3: b'premium, 4: b'very good, 5: b'fair;
#
# for color column is 0: b'D, 1: b'E, 2: b'F, 3: b'G 4: b'H, 5: b'I, 6: b'J;
#
# for clarity column is 0: b'I1, 1: b'IF, 2: b'SI1, 3: b'SI2, 4: b'VS1, 5: b'VS2, 6: b'VVS1, 7: b'VVS2.

# %%
data1=data1.drop('cut',axis=1)
data1=data1.drop('color',axis=1)
data1=data1.drop('clarity',axis=1)
data1
# Out:
#        carat   price   'x'   'y'   'z'  cut_n  color_n  clarity_n
# 0       0.23   326.0  3.95  3.98  2.43      2        1          3
# 1       0.21   326.0  3.89  3.84  2.31      3        1          2
# 2       0.23   327.0  4.05  4.07  2.31      1        1          4
# 3       0.29   334.0  4.20  4.23  2.63      3        5          5
# 4       0.31   335.0  4.34  4.35  2.75      1        6          3
# ...      ...     ...   ...   ...   ...    ...      ...        ...
# 53935   0.72  2757.0  5.75  5.76  3.50      2        0          2
# 53936   0.72  2757.0  5.69  5.75  3.61      1        0          2
# 53937   0.70  2757.0  5.66  5.68  3.56      4        0          2
# 53938   0.86  2757.0  6.15  6.12  3.74      3        4          3
# 53939   0.75  2757.0  5.83  5.87  3.64      2        0          3
#
# [53940 rows x 8 columns]

# %%
#Choosing the features as x and the target as y
x=data1[["carat","'x'","'y'","'z'","color_n","cut_n","clarity_n"]]
y=data1['price']
data1
# Out:
#        carat   price   'x'   'y'   'z'  cut_n  color_n  clarity_n
# 0       0.23   326.0  3.95  3.98  2.43      2        1          3
# 1       0.21   326.0  3.89  3.84  2.31      3        1          2
# 2       0.23   327.0  4.05  4.07  2.31      1        1          4
# 3       0.29   334.0  4.20  4.23  2.63      3        5          5
# 4       0.31   335.0  4.34  4.35  2.75      1        6          3
# ...      ...     ...   ...   ...   ...    ...      ...        ...
# 53935   0.72  2757.0  5.75  5.76  3.50      2        0          2
# 53936   0.72  2757.0  5.69  5.75  3.61      1        0          2
# 53937   0.70  2757.0  5.66  5.68  3.56      4        0          2
# 53938   0.86  2757.0  6.15  6.12  3.74      3        4          3
# 53939   0.75  2757.0  5.83  5.87  3.64      2        0          3
#
# [53940 rows x 8 columns]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split( x, y, test_size=0.2, random_state=40)

from sklearn.neighbors import KNeighborsRegressor
knn_model = KNeighborsRegressor(n_neighbors=3)

knn_model.fit(x_train, y_train)
# Out:
# KNeighborsRegressor(n_neighbors=3)

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
train_preds = knn_model.predict(x_train) #evaluate the prediction error on the training data (the result should be relatively good)
mse = mean_squared_error(y_train, train_preds)
rmse = sqrt(mse)
print("the rmse result for the training data is :", rmse)
#RMSD is always non-negative, and a value of 0 (almost never achieved in practice) would indicate a perfect fit to the data. 
#In general, a lower RMSD is better than a higher one
# Out:
# the rmse result for the training data is : 440.4380285352047

# %%
test_preds = knn_model.predict(x_test) #evaluate the predictive performances on the test set
mse = mean_squared_error(y_test, test_preds)
rmse = sqrt(mse)
print("the rmse result for the testing data is :", rmse)
# Out:
# the rmse result for the testing data is : 642.0316665456959

# %%
data2=data 
data2=data2.drop('depth',axis=1)
data2=data2.drop('table',axis=1)
data2=data2.drop('cut',axis=1)
data2=data2.drop('color',axis=1)
data2=data2.drop('clarity',axis=1)
data2
# Out:
#        carat   price   'x'   'y'   'z'
# 0       0.23   326.0  3.95  3.98  2.43
# 1       0.21   326.0  3.89  3.84  2.31
# 2       0.23   327.0  4.05  4.07  2.31
# 3       0.29   334.0  4.20  4.23  2.63
# 4       0.31   335.0  4.34  4.35  2.75
# ...      ...     ...   ...   ...   ...
# 53935   0.72  2757.0  5.75  5.76  3.50
# 53936   0.72  2757.0  5.69  5.75  3.61
# 53937   0.70  2757.0  5.66  5.68  3.56
# 53938   0.86  2757.0  6.15  6.12  3.74
# 53939   0.75  2757.0  5.83  5.87  3.64
#
# [53940 rows x 5 columns]

# %%
#Choosing the features as x and the target as y
x2=data2[["carat","'x'","'y'","'z'"]]
y2=data2['price']

# %%
from sklearn.model_selection import train_test_split
x2_train, x2_test, y2_train, y2_test = train_test_split( x2, y2, test_size=0.2, random_state=40)

from sklearn.neighbors import KNeighborsRegressor
knn_model = KNeighborsRegressor(n_neighbors=3)

knn_model.fit(x2_train, y2_train)
# Out:
# KNeighborsRegressor(n_neighbors=3)

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
train_preds = knn_model.predict(x2_train) #evaluate the prediction error on the training data (the result should be relatively good)
mse = mean_squared_error(y2_train, train_preds)
rmse = sqrt(mse)
print("the rmse result for the training data is :", rmse)
#RMSD is always non-negative, and a value of 0 (almost never achieved in practice) would indicate a perfect fit to the data. 
#In general, a lower RMSD is better than a higher one
# Out:
# the rmse result for the training data is : 1072.079961735282

# %%
test_preds = knn_model.predict(x2_test) #evaluate the predictive performances on the test set
mse = mean_squared_error(y2_test, test_preds)
rmse = sqrt(mse)
print("the rmse result for the testing data is :", rmse)
# Out:
# the rmse result for the testing data is : 1549.6566711695823

# %% [markdown]
# ####  Random Forest

# %%
x = data1.drop('price', axis = 1)
y = data1['price'] 
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 40)

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(n_estimators = 120, criterion= 'squared_error')
model.fit(x_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=120)

# %%
y_pred = model.predict(x_test)

# %%
rmse = float(format(np.sqrt(mean_squared_error(y_test, y_pred)),'.3f'))
print("\nRMSE:\n",rmse)
#The RMSE of a model determines the absolute fit of the model to the data. 
#In other words, it indicates how close the actual data points are to the model’s predicted values.
# Out:
# RMSE:
#  569.121

# %% [markdown]
# This model isn't performing very well with a relatively high rmse.

# %% [markdown]
# After testing multiple supervised learning methods, the best one is Polynomial Regression
